# %% [markdown]
# ## Sarsa
# 1. 初始化Q(s, a)
#
# 2. for 序列e = 1 → E do:
#    - 得到初始状态s
#    - 用ε-greedy 策略根据Q选择当前状态s下的动作a
#
#    - for 时间步t = 1 → T do:
#      - 得到环境反馈的r, s'
#      - 用ε-greedy 策略根据Q选择当前状态s'下的动作a'
#      - Q(s, a) ← Q(s, a) + α[r + γQ(s', a') - Q(s, a)]
#      - s ← s', a ← a'
#    - end for
#
# 3. end for

# %%
# %matplotlib inline
from Sarsa import *
if __name__ == "__main__":
    episodes_list = []
    return_list = []
    agent, env, episodes_list, return_list = doSarsa()
    action_meaning = ['^', 'v', '<', '>']
    print('Sarsa算法最终收敛得到的策略为：')
    print_agent(agent, env, action_meaning, list(range(37, 47)), [47])
    episodes_list = list(range(len(return_list)))
    plt.plot(episodes_list, return_list)
    plt.xlabel('Episodes')
    plt.ylabel('Returns')
    plt.title('Sarsa on {}'.format('Cliff Walking'))
    plt.show()
# Out:
# ...
# Iteration 9: 100%|██████████| 50/50 [00:00<00:00, 1365.85it/s, episode=500, return=-18.900]
# Sarsa算法最终收敛得到的策略为：
# ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ovoo
# ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ovoo
# ^ooo ooo> ^ooo ooo> ooo> ooo> ooo> ^ooo ^ooo ooo> ooo> ovoo
# ^ooo **** **** **** **** **** **** **** **** **** **** EEEE

# %% [markdown]
# ## n-step Sarsa
# 1. 初始化Q(s, a)
#
# 2. for 序列e = 1 → E do:
#    - 得到初始状态s
#    - 用ε-greedy 策略根据Q选择当前状态s下的动作a
#
#    - for 时间步t = 1 → T do:
#      - 得到环境反馈的r, s'
#      - 用ε-greedy 策略根据Q选择当前状态s'下的动作a'
#      - $Q(s, a) ← Q(s, a) + α[r_t + \gamma r_{t +1} + \cdots + \gamma^n Q(s_{t + n}, a_{t + n}) - Q(s_t, a_t)]$
#      - s ← s', a ← a'
#    - end for
#
# 3. end for

# %%
# 做n=5的Sarsa算法
# %matplotlib inline
from nSarsa import *
if __name__ == "__main__":
    pisodes_list = []
    return_list = []
    agent, env, episodes_list, return_list = doneq5Sarsa()
    action_meaning = ['^', 'v', '<', '>']
    print('Sarsa算法最终收敛得到的策略为：')
    print_agent(agent, env, action_meaning, list(range(37, 47)), [47])
    plt.plot(episodes_list, return_list)
    plt.xlabel('Episodes')
    plt.ylabel('Returns')
    plt.title('5-step Sarsa on {}'.format('Cliff Walking'))
    plt.show()
# Out:
# ...
# Iteration 9: 100%|██████████| 50/50 [00:00<00:00, 2078.57it/s, episode=500, return=-19.100]
# Sarsa算法最终收敛得到的策略为：
# ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ovoo
# ^ooo ^ooo ^ooo oo<o ^ooo ^ooo ^ooo ^ooo ooo> ooo> ^ooo ovoo
# ooo> ^ooo ^ooo ^ooo ^ooo ^ooo ^ooo ooo> ooo> ^ooo ooo> ovoo
# ^ooo **** **** **** **** **** **** **** **** **** **** EEEE

# %%
# 做n=10的Sarsa算法
# %matplotlib inline
from nSarsa import *
if __name__ == "__main__":
    pisodes_list = []
    return_list = []
    agent, env, episodes_list, return_list = doneq10Sarsa()
    action_meaning = ['^', 'v', '<', '>']
    print('Sarsa算法最终收敛得到的策略为：')
    print_agent(agent, env, action_meaning, list(range(37, 47)), [47])
    plt.plot(episodes_list, return_list)
    plt.xlabel('Episodes')
    plt.ylabel('Returns')
    plt.title('10-step Sarsa on {}'.format('Cliff Walking'))
    plt.show()
# Out:
# ...
# Iteration 9: 100%|██████████| 50/50 [00:00<00:00, 1712.58it/s, episode=500, return=-22.200]
# Sarsa算法最终收敛得到的策略为：
# ooo> ooo> ovoo ooo> ooo> ooo> ovoo oo<o ooo> ^ooo ooo> ovoo
# ^ooo ^ooo ooo> ^ooo ^ooo ^ooo ooo> ooo> ooo> ooo> ooo> ovoo
# ^ooo oo<o ooo> ^ooo oo<o ^ooo ^ooo ^ooo ^ooo ^ooo ooo> ovoo
# ^ooo **** **** **** **** **** **** **** **** **** **** EEEE

# %%
# 做n=5的Sarsa算法
# %matplotlib inline
from nSarsa import *
if __name__ == "__main__":
    pisodes_list = []
    return_list = []
    agent, env, episodes_list, return_list = doneq20Sarsa()
    action_meaning = ['^', 'v', '<', '>']
    print('Sarsa算法最终收敛得到的策略为：')
    print_agent(agent, env, action_meaning, list(range(37, 47)), [47])
    plt.plot(episodes_list, return_list)
    plt.xlabel('Episodes')
    plt.ylabel('Returns')
    plt.title('20-step Sarsa on {}'.format('Cliff Walking'))
    plt.show()
# Out:
# ...
# Iteration 9: 100%|██████████| 50/50 [00:00<00:00, 1565.49it/s, episode=500, return=-19.300]
# Sarsa算法最终收敛得到的策略为：
# ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ovoo
# ^ooo ^ooo oo<o ^ooo ^ooo ooo> ^ooo ^ooo ooo> ^ooo ovoo ovoo
# ^ooo ^ooo ^ooo ooo> ^ooo ooo> ooo> ^ooo ooo> ooo> ooo> ovoo
# ^ooo **** **** **** **** **** **** **** **** **** **** EEEE

# %% [markdown]
# ## Q-learning
# >Q-learning是一种off-policy的控制算法，使用ε-greedy策略对环境进行探索，但采用greedy策略改进自身的策略。
# 1. 初始化Q(s, a)
#
# 2. for 序列e = 1 → E do:
#    - 得到初始状态s
#    - for 时间步t = 1 → T do:
#      - 用ε-greedy 策略根据Q选择当前状态s下的动作a
#      - 得到环境反馈的r, s'
#      - Q(s, a) ← Q(s, a) + α[r + γmax_a' Q(s', a') - Q(s, a)]
#      - s ← s'
#    - end for
#
# 3. end for

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from Qlearning import *
np.random.seed(0)
epsilon = 0.1
alpha = 0.1
gamma = 0.9
ncol = 12
nrow  = 4
agent = QLearning(ncol, nrow, epsilon, alpha, gamma)
num_episodes = 500  # 智能体在环境中运行的序列的数量

return_list = []  # 记录每一条序列的回报
for i in range(10):  # 显示10个进度条
    # tqdm的进度条功能
    with tqdm(total=int(num_episodes / 10), desc='Iteration %d' % i) as pbar:
        for i_episode in range(int(num_episodes / 10)):  # 每个进度条的序列数
            episode_return = 0
            state = env.reset()
            done = False
            while not done:
                action = agent.take_action(state)
                next_state, reward, done = env.step(action)
                episode_return += reward  # 这里回报的计算不进行折扣因子衰减
                agent.update(state, action, reward, next_state)
                state = next_state
            return_list.append(episode_return)
            if (i_episode + 1) % 10 == 0:  # 每10条序列打印一下这10条序列的平均回报
                pbar.set_postfix({
                    'episode':
                    '%d' % (num_episodes / 10 * i + i_episode + 1),
                    'return':
                    '%.3f' % np.mean(return_list[-10:])
                })
            pbar.update(1)

episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('Q-learning on {}'.format('Cliff Walking'))
plt.show()

action_meaning = ['^', 'v', '<', '>']
print('Q-learning算法最终收敛得到的策略为：')
print_agent(agent, env, action_meaning, list(range(37, 47)), [47])
# Out:
# ...
# Iteration 9: 100%|██████████| 50/50 [00:00<00:00, 3122.39it/s, episode=500, return=-61.700]
# Q-learning算法最终收敛得到的策略为：
# ^ooo ovoo ovoo ^ooo ^ooo ovoo ooo> ^ooo ^ooo ooo> ooo> ovoo
# ooo> ooo> ooo> ooo> ooo> ooo> ^ooo ooo> ooo> ooo> ooo> ovoo
# ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ooo> ovoo
# ^ooo **** **** **** **** **** **** **** **** **** **** EEEE
